# %% [markdown]
# <a href="https://colab.research.google.com/github/VivekShahare04/Leetcode-frequency-Predictor/blob/main/prediction_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('combined_output.csv')
df
# Out:
#          ID                                          Title Acceptance  \
# 0       273                       Integer to English Words      27.1%
# 1       146                                      LRU Cache      33.2%
# 2       387             First Unique Character in a String      53.4%
# 3       236        Lowest Common Ancestor of a Binary Tree      45.7%
# 4       353                              Design Snake Game      34.2%
# ...     ...                                            ...        ...
# 20448   309  Best Time to Buy and Sell Stock with Cooldown      47.4%
# 20449  1431       Kids With the Greatest Number of Candies      88.9%
# 20450   237                   Delete Node in a Linked List      63.8%
# 20451    35                         Search Insert Position      42.6%
# 20452   797                All Paths From Source to Target      77.9%
#
#       Difficulty  Frequency                             Leetcode Question Link
# ...

# %%
new_order = ['ID','Title','Difficulty','Leetcode Question Link','Acceptance','Frequency']
new_order
# Out:
# ['ID',
#  'Title',
#  'Difficulty',
#  'Leetcode Question Link',
#  'Acceptance',
#  'Frequency']

# %%
df = df[new_order]

# %%
df
# Out:
#          ID                                          Title Difficulty  \
# 0       273                       Integer to English Words       Hard
# 1       146                                      LRU Cache     Medium
# 2       387             First Unique Character in a String       Easy
# 3       236        Lowest Common Ancestor of a Binary Tree     Medium
# 4       353                              Design Snake Game     Medium
# ...     ...                                            ...        ...
# 20448   309  Best Time to Buy and Sell Stock with Cooldown     Medium
# 20449  1431       Kids With the Greatest Number of Candies       Easy
# 20450   237                   Delete Node in a Linked List       Easy
# 20451    35                         Search Insert Position       Easy
# 20452   797                All Paths From Source to Target     Medium
#
#                                   Leetcode Question Link Acceptance  Frequency
# ...

# %%
df.describe()
# Out:
#                  ID     Frequency
# count  20453.000000  20453.000000
# mean     406.495673      0.341518
# std      372.868638      0.694764
# min        1.000000      0.000000
# 25%      103.000000      0.016779
# 50%      279.000000      0.066366
# 75%      665.000000      0.297252
# max     1547.000000      6.080030

# %%
df.isnull().sum()
# Out:
# ID                        0
# Title                     0
# Difficulty                0
# Leetcode Question Link    0
# Acceptance                0
# Frequency                 0
# dtype: int64

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
#          ID                                          Title Difficulty  \
# 47       15                                           3Sum     Medium
# 68      200                              Number of Islands     Medium
# 70        4                    Median of Two Sorted Arrays       Hard
# 83     1271                                       Hexspeak       Easy
# 103     362                             Design Hit Counter     Medium
# ...     ...                                            ...        ...
# 20448   309  Best Time to Buy and Sell Stock with Cooldown     Medium
# 20449  1431       Kids With the Greatest Number of Candies       Easy
# 20450   237                   Delete Node in a Linked List       Easy
# 20451    35                         Search Insert Position       Easy
# 20452   797                All Paths From Source to Target     Medium
#
#                                   Leetcode Question Link Acceptance  Frequency
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Difficulty'] = le.fit_transform(df['Difficulty'])
def convert_percentage_to_float(value):
    if isinstance(value, str) and '%' in value:
        return float(value.replace('%', '')) / 100.0
    return float(value)

df['Frequency'] = df['Frequency'].apply(convert_percentage_to_float)
df['Acceptance'] = df['Acceptance'].apply(convert_percentage_to_float)

# %%
X = df[['Difficulty']]
Y = df[['Frequency', 'Acceptance']]

# %%
X
# Out:
#        Difficulty
# 0               1
# 1               2
# 2               0
# 3               2
# 4               2
# ...           ...
# 20448           2
# 20449           0
# 20450           0
# 20451           0
# 20452           2
#
# [20453 rows x 1 columns]

# %%
Y
# Out:
#        Frequency  Acceptance
# 0       0.378620       0.271
# 1       0.322546       0.332
# 2       0.293872       0.534
# 3       0.270510       0.457
# 4       0.214436       0.342
# ...          ...         ...
# 20448   0.006401       0.474
# 20449   0.005928       0.889
# 20450   0.005145       0.638
# 20451   0.004647       0.426
# 20452   0.002470       0.779
#
# [20453 rows x 2 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
from sklearn.multioutput import MultiOutputRegressor
multi_target_model = MultiOutputRegressor(rf)

# %%
multi_target_model.fit(X_train, Y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(random_state=42))

# %%
Y_pred = multi_target_model.predict(X_test)

# %%
mse_freq = mean_squared_error(Y_test['Frequency'], Y_pred[:, 0])
mse_acc = mean_squared_error(Y_test['Acceptance'], Y_pred[:, 1])

# %%
print(mse_acc)
print(mse_freq)
# Out:
# 0.014233622099583764
# 0.4718887603687417

# %%
import pickle

# Assume 'model' is your trained model
model = multi_target_model  # Replace this with your actual model

# Save the model to a file
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

print("Model saved to 'model.pkl'")
# Out:
# Model saved to 'model.pkl'

# %%
import pickle

# Load the model from the file
with open('model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

print("Model loaded from 'model.pkl'")
# Out:
# Model loaded from 'model.pkl'

# %%
from google.colab import files
files.download('model.pkl')  # Download the 'model.pkl' file to your computer
